# %% [markdown]
# # Welcome to my Jupyter Notebook
#
# ### My holiday preference is Japan.
#
# ![TokyoMain.jpg](attachment:TokyoMain.jpg) ![Kyoto-Yasaka-Pagoda.jpg](attachment:Kyoto-Yasaka-Pagoda.jpg)
#
# ## Here's a video which highlights why Japan is my holiday preference.
# <a href="http://www.youtube.com/watch?feature=player_embedded&v=fyAXhMU-fbc
# " target="_blank"><img src="http://img.youtube.com/vi/fyAXhMU-fbcE/0.jpg"
# alt="IMAGE ALT TEXT HERE" width="240" height="180" border="10" /></a>

# %%
name = input("Hello! What is your name? ")
def greeting(name):
    print("Your name is:",name,", cool!")
    sentence = print(name,", thanks for checking out my Jupyter notebook")
    return sentence
# Out:
# Hello! What is your name? Gareth

# %% [markdown]
# <font color = blue >Here's a photo of myself. </font>
# ![Guitar.jpg](attachment:Guitar.jpg)

# %%
def holiday_dest():
    destination = input("Where would you like to go on holiday?")
    return print('You want to go to',destination,'? Nice!')

# %%
print("I can't find any (good) photos of myself there!")
# Out:
# I can't find any (good) photos of myself there!

# %% [markdown]
# 1. <font color=red>O</font>
# 2. <font color=blue>h</font>
# 3. <font color=green>N</font>
# 4. <font color=pink>o!</font>

# %%
holiday_dest()
# Out:
# Where would you like to go on holiday?Tokyo
# You want to go to Tokyo ? Nice!

# %% [markdown]
# ## Things to do in Tokyo / Japan
# - Explore temples / see the culture
# > - Visit guitar shops (Japan has lots of rare guitars)
# >>>>> - Eat sushi / ramen!
# > - Go drinking in Shibuya
# - Get lost in an Arcade
